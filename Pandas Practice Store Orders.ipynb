# %%
import pandas as pd

# %%
#Import dataset
data = pd.read_csv('SuperStoreOrders.csv')
#Create Dataframe
df = pd.DataFrame(data)
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Draâ        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ...         category sub_category  \
# 0       Africa  ...  Office Supplies      Storage
# 1      Oceania  ...  Office Supplies     Supplies
# 2         EMEA  ...  Office Supplies      Storage
# 3        North  ...  Office Supplies        Paper
# 4      Oceania  ...        Furniture  Furnishings
# ...        ...  ...              ...          ...
# 51285     West  ...  Office Supplies      Binders
# 51286   Africa  ...  Office Supplies      Binders
# 51287  Central  ...  Office Supplies       Labels
# 51288    North  ...  Office Supplies       Labels
# 51289     West  ...  Office Supplies    Fasteners
#
#                                           product_name sales quantity  \
# 0                                  Tenex Lockers, Blue   408        2
# 1                             Acme Trimmer, High Speed   120        3
# 2                              Tenex Box, Single Width    66        4
# 3                          Enermax Note Cards, Premium    45        3
# 4                           Eldon Light Bulb, Duo Pack   114        5
# ...                                                ...   ...      ...
# 51285  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl    14        2
# 51286          Wilson Jones Hole Reinforcements, Clear     4        1
# 51287           Hon Color Coded Labels, 5000 Label Set    26        3
# 51288           Hon Legal Exhibit Labels, Alphabetical     7        1
# 51289                              Bagged Rubber Bands     3        3
#
#        discount    profit  shipping_cost  order_priority  year
# 0           0.0  106.1400          35.46          Medium  2011
# 1           0.1   36.0360           9.72          Medium  2011
# 2           0.0   29.6400           8.17            High  2011
# 3           0.5  -26.0550           4.82            High  2011
# 4           0.1   37.7700           4.70          Medium  2011
# ...         ...       ...            ...             ...   ...
# 51285       0.2    4.5188           0.89          Medium  2014
# 51286       0.0    0.4200           0.49          Medium  2014
# 51287       0.0   12.3600           0.35          Medium  2014
# 51288       0.0    0.5600           0.20          Medium  2014
# 51289       0.2   -0.6048           0.17          Medium  2014
#
# [51290 rows x 21 columns]

# %%
#Add new column Gross Profit
df['gross_profit'] = df['profit']-df['shipping_cost']
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Draâ        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ... sub_category  \
# 0       Africa  ...      Storage
# 1      Oceania  ...     Supplies
# 2         EMEA  ...      Storage
# 3        North  ...        Paper
# 4      Oceania  ...  Furnishings
# ...        ...  ...          ...
# 51285     West  ...      Binders
# 51286   Africa  ...      Binders
# 51287  Central  ...       Labels
# 51288    North  ...       Labels
# 51289     West  ...    Fasteners
#
#                                           product_name sales quantity  \
# 0                                  Tenex Lockers, Blue   408        2
# 1                             Acme Trimmer, High Speed   120        3
# 2                              Tenex Box, Single Width    66        4
# 3                          Enermax Note Cards, Premium    45        3
# 4                           Eldon Light Bulb, Duo Pack   114        5
# ...                                                ...   ...      ...
# 51285  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl    14        2
# 51286          Wilson Jones Hole Reinforcements, Clear     4        1
# 51287           Hon Color Coded Labels, 5000 Label Set    26        3
# 51288           Hon Legal Exhibit Labels, Alphabetical     7        1
# 51289                              Bagged Rubber Bands     3        3
#
#        discount    profit  shipping_cost  order_priority  year gross_profit
# 0           0.0  106.1400          35.46          Medium  2011      70.6800
# 1           0.1   36.0360           9.72          Medium  2011      26.3160
# 2           0.0   29.6400           8.17            High  2011      21.4700
# 3           0.5  -26.0550           4.82            High  2011     -30.8750
# 4           0.1   37.7700           4.70          Medium  2011      33.0700
# ...         ...       ...            ...             ...   ...          ...
# 51285       0.2    4.5188           0.89          Medium  2014       3.6288
# 51286       0.0    0.4200           0.49          Medium  2014      -0.0700
# 51287       0.0   12.3600           0.35          Medium  2014      12.0100
# 51288       0.0    0.5600           0.20          Medium  2014       0.3600
# 51289       0.2   -0.6048           0.17          Medium  2014      -0.7748
#
# [51290 rows x 22 columns]

# %%
#Retrieve the sales from 10 to 400
sales = df[(df['sales'] >= 10) & (df['sales'] <= 400)]
sales
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 1        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...                ...         ...       ...             ...
# 51282     UP-2014-4410  31-12-2014  4/1/2015  Standard Class
# 51283    IN-2014-23754  31-12-2014  7/1/2015  Standard Class
# 51284   MX-2014-108574  31-12-2014  4/1/2015  Standard Class
# 51285   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51287   MX-2014-110527  31-12-2014  2/1/2015    Second Class
#
#           customer_name      segment            state        country market  \
# 1           Joseph Holt     Consumer  New South Wales      Australia   APAC
# 2         Annie Thurman     Consumer         Budapest        Hungary   EMEA
# 3          Eugene Moren  Home Office        Stockholm         Sweden     EU
# 4           Joseph Holt     Consumer  New South Wales      Australia   APAC
# 5           Joseph Holt     Consumer  New South Wales      Australia   APAC
# ...                 ...          ...              ...            ...    ...
# 51282      Guy Thornton     Consumer     Zaporizhzhya        Ukraine   EMEA
# 51283      Kalyca Meade    Corporate        Guangdong          China   APAC
# 51284     Julia Barnett  Home Office       Tamaulipas         Mexico  LATAM
# 51285        Erica Bern    Corporate       California  United States     US
# 51287  Charlotte Melton     Consumer          Managua      Nicaragua  LATAM
#
#            region  ... sub_category  \
# 1         Oceania  ...     Supplies
# 2            EMEA  ...      Storage
# 3           North  ...        Paper
# 4         Oceania  ...  Furnishings
# 5         Oceania  ...        Paper
# ...           ...  ...          ...
# 51282        EMEA  ...       Labels
# 51283  North Asia  ...        Paper
# 51284       North  ...       Labels
# 51285        West  ...      Binders
# 51287     Central  ...       Labels
#
#                                           product_name sales quantity  \
# 1                             Acme Trimmer, High Speed   120        3
# 2                              Tenex Box, Single Width    66        4
# 3                          Enermax Note Cards, Premium    45        3
# 4                           Eldon Light Bulb, Duo Pack   114        5
# 5              Eaton Computer Printout Paper, 8.5 x 11    55        2
# ...                                                ...   ...      ...
# 51282                 Avery Round Labels, Alphabetical    28        4
# 51283                       Eaton Note Cards, 8.5 x 11    79        3
# 51284         Novimex Legal Exhibit Labels, Adjustable    17        3
# 51285  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl    14        2
# 51287           Hon Color Coded Labels, 5000 Label Set    26        3
#
#        discount   profit  shipping_cost  order_priority  year gross_profit
# 1           0.1  36.0360           9.72          Medium  2011      26.3160
# 2           0.0  29.6400           8.17            High  2011      21.4700
# 3           0.5 -26.0550           4.82            High  2011     -30.8750
# 4           0.1  37.7700           4.70          Medium  2011      33.0700
# 5           0.1  15.3420           1.80          Medium  2011      13.5420
# ...         ...      ...            ...             ...   ...          ...
# 51282       0.0   6.1200           1.70          Medium  2014       4.4200
# 51283       0.0  25.3800           1.41          Medium  2014      23.9700
# 51284       0.0   0.6600           1.32          Medium  2014      -0.6600
# 51285       0.2   4.5188           0.89          Medium  2014       3.6288
# 51287       0.0  12.3600           0.35          Medium  2014      12.0100
#
# [40004 rows x 22 columns]

# %%
#Convert the string into int
df['sales'] = df['sales'].str.replace(',', '').astype(int)
print(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9996\2912092028.py in <module>
# ----> 1 df['sales'] = df['sales'].str.replace(',', '').astype(int)
#       2 print(df.dtypes)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     175         from pandas.core.arrays.string_ import StringDtype
#     176
# --> 177         self._inferred_dtype = self._validate(data)
#     178         self._is_categorical = is_categorical_dtype(data.dtype)
#     179         self._is_string = isinstance(data.dtype, StringDtype)
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in _validate(data)
#     229
#     230         if inferred_dtype not in allowed_types:
# --> 231             raise AttributeError("Can only use .str accessor with string values!")
#     232         return inferred_dtype
#     233
#
# AttributeError: Can only use .str accessor with string values!

# %%
#Get all products remove duplication with unique function
all_products = df['product_name'].unique()
#Group the region column for check the availablity of the product
grouped = df.groupby('region')
not_available_df = pd.DataFrame(columns=['Region', 'Products Not Available'])
#Loop for check the region and product one bt one
for region_name, region_df in grouped:
    available = region_df['product_name'].unique()
    #Remove the available products from all products
    not_available = set(all_products) - set(available)
    #Dictionary for new dataframe
    region_data = {'Region': region_name, 'Products Not Available': not_available}
    not_available_df = pd.concat([not_available_df, pd.DataFrame([region_data])], ignore_index=True)
#Print the result
print(not_available_df)
# Out:
#             Region                             Products Not Available
# 0           Africa  {Black & Decker Filter for Double Action Dustb...
# 1           Canada  {Elite Scissors, High Speed, Nokia Speaker Pho...
# 2        Caribbean  {Elite Scissors, High Speed, Nokia Speaker Pho...
# 3          Central  {Eldon 200 Class Desk Accessories, Smoke, Chro...
# 4     Central Asia  {Green Bar Cards & Envelopes, Premium, Nokia S...
# 5             EMEA  {Black & Decker Filter for Double Action Dustb...
# 6             East  {Elite Scissors, High Speed, Green Bar Cards &...
# 7            North  {Black & Decker Filter for Double Action Dustb...
# 8       North Asia  {Green Bar Cards & Envelopes, Premium, Nokia S...
# 9          Oceania  {Elite Scissors, High Speed, Black & Decker Fi...
# 10           South  {JBL Micro Wireless Portable Bluetooth Speaker...
# 11  Southeast Asia  {Elite Scissors, High Speed, Black & Decker Fi...
# 12            West  {Elite Scissors, High Speed, Green Bar Cards &...

# %%
not_available_df.size
# Out:
# 52

# %%
not_available_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   region                  13 non-null     object
#  1   not_available_products  13 non-null     object
# dtypes: object(2)
# memory usage: 336.0+ bytes

# %%
not_available_df.head(26)
# Out:
#             Region                             Products Not Available
# 0           Africa  {Black & Decker Filter for Double Action Dustb...
# 1           Canada  {Elite Scissors, High Speed, Nokia Speaker Pho...
# 2        Caribbean  {Elite Scissors, High Speed, Nokia Speaker Pho...
# 3          Central  {Eldon 200 Class Desk Accessories, Smoke, Chro...
# 4     Central Asia  {Green Bar Cards & Envelopes, Premium, Nokia S...
# 5             EMEA  {Black & Decker Filter for Double Action Dustb...
# 6             East  {Elite Scissors, High Speed, Green Bar Cards &...
# 7            North  {Black & Decker Filter for Double Action Dustb...
# 8       North Asia  {Green Bar Cards & Envelopes, Premium, Nokia S...
# 9          Oceania  {Elite Scissors, High Speed, Black & Decker Fi...
# 10           South  {JBL Micro Wireless Portable Bluetooth Speaker...
# 11  Southeast Asia  {Elite Scissors, High Speed, Black & Decker Fi...
# 12            West  {Elite Scissors, High Speed, Green Bar Cards &...

# %%
#Sort the quantity column using sort and lambda function with groupby method
sorted_df = df.groupby('quantity').apply(lambda x: x.sort_values(by='quantity'))
sorted_df
